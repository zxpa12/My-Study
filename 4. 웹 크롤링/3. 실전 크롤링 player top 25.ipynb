# %%
# 라이브러리 불러오기
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
# requests.get()으로 url 정보 요청하기
headers = {'User-Agent' : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36"}

url = "https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop"

r= requests.get(url, headers=headers)
r.status_code
# Out:
# 200

# %%
# BeautifulSoup()으로 웹페이지 분석 준비하기
soup = BeautifulSoup(r.text, 'html.parser') # r.content 대신 r.text 도 가능
print(soup)
# Out:
# <!DOCTYPE html>
#
# <!-- paulirish.com/2008/conditional-stylesheets-vs-css-hacks-answer-neither/ -->
# <!--[if IE 7]>
# <html class="ie7 oldie" lang="en"> <![endif]-->
# <!--[if IE 8]>
# <html class="no-js lt-ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en">
# <!--<![endif]-->
# <head>
# <script type="text/javascript">
#     !function () { var e = function () { var e, t = "__tcfapiLocator", a = [], n = window; for (; n;) { try { if (n.frames[t]) { e = n; break } } catch (e) { } if (n === window.top) break; n = n.parent } e || (!function e() { var a = n.document, r = !!n.frames[t]; if (!r) if (a.body) { var i = a.createElement("iframe"); i.style.cssText = "display:none", i.name = t, a.body.appendChild(i) } else setTimeout(e, 5); return !r }(), n.__tcfapi = function () { for (var e, t = arguments.length, n = new Array(t), r = 0; r < t; r++)n[r] = arguments[r]; if (!n.length) return a; if ("setGdprApplies" === n[0]) n.length > 3 && 2 === parseInt(n[1], 10) && "boolean" == typeof n[3] && (e = n[3], "function" == typeof n[2] && n[2]("set", !0)); else if ("ping" === n[0]) { var i = { gdprApplies: e, cmpLoaded: !1, cmpStatus: "stub" }; "function" == typeof n[2] && n[2](i) } else a.push(n) }, n.addEventListener("message", (function (e) { var t = "string" == typeof e.data, a = {}; try { a = t ? JSON.parse(e.data) : e.data } catch (e) { } var n = a.__tcfapiCall; n && window.__tcfapi(n.command, n.version, (function (a, r) { var i = { __tcfapiReturn: { returnValue: a, success: r, callId: n.callId } }; t && (i = JSON.stringify(i)), e.source.postMessage(i, "*") }), n.parameter) }), !1)) }; "undefined" != typeof module ? module.exports = e : e() }();
# </script>
# <script>
# window._sp_ = {
#     config: {"accountId":1254,"propertyId":7427,"baseEndpoint":"https://cdn.privacy-mgmt.com"}}
# </script>
# <script src="https://cdn.privacy-mgmt.com/wrapperMessagingWithoutDetection.js"></script>
# <script src="https://unpkg.com/micromodal/dist/micromodal.min.js"></script>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="x-ua-compatible"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="#1a3151" name="theme-color">
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/favicon-16x16.png" rel="shortcut icon" sizes="16x16"/>
# <link href="/android-chrome-192x192.png" rel="shortcut icon" sizes="192x192"/>
# <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, user-scalable=no" name="viewport">
# <meta content="article" property="og:type"/>
# <meta content="https://tmssl.akamaized.net/images/tm_logo.png" property="og:image"/>
# <meta content="" property="og:description"/>
# <meta content="Most valuable players" property="og:title"/>
# <meta content="https://_/marktwertetop/wertvollstespieler" property="og:url"/>
# <link href="https://www.transfermarkt.de/marktwertetop/wertvollstespieler" hreflang="de" rel="alternate">
# <link href="https://www.transfermarkt.de/marktwertetop/wertvollstespieler" hreflang="de-LU" rel="alternate">
# <link href="https://www.transfermarkt.at/marktwertetop/wertvollstespieler" hreflang="de-AT" rel="alternate">
# <link href="https://www.transfermarkt.ch/marktwertetop/wertvollstespieler" hreflang="de-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.com.tr/marktwertetop/wertvollstespieler" hreflang="tr" rel="alternate"/>
# <link href="https://www.transfermarkt.it/marktwertetop/wertvollstespieler" hreflang="it-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.it/marktwertetop/wertvollstespieler" hreflang="it" rel="alternate"/>
# <link href="https://www.transfermarkt.pl/marktwertetop/wertvollstespieler" hreflang="pl" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/marktwertetop/wertvollstespieler" hreflang="en-GB" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/marktwertetop/wertvollstespieler" hreflang="en-IE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/marktwertetop/wertvollstespieler" hreflang="es" rel="alternate"/>
# <link href="https://www.transfermarkt.es/marktwertetop/wertvollstespieler" hreflang="es-ES" rel="alternate"/>
# <link href="https://www.transfermarkt.es/marktwertetop/wertvollstespieler" hreflang="es-CL" rel="alternate"/>
# <link href="https://www.transfermarkt.es/marktwertetop/wertvollstespieler" hreflang="es-VE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/marktwertetop/wertvollstespieler" hreflang="es-PE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/marktwertetop/wertvollstespieler" hreflang="es-EC" rel="alternate"/>
# <link href="https://www.transfermarkt.es/marktwertetop/wertvollstespieler" hreflang="es-CU" rel="alternate"/>
# <link href="https://www.transfermarkt.nl/marktwertetop/wertvollstespieler" hreflang="nl" rel="alternate"/>
# <link href="https://www.transfermarkt.pt/marktwertetop/wertvollstespieler" hreflang="pt" rel="alternate"/>
# <link href="https://www.transfermarkt.ru/marktwertetop/wertvollstespieler" hreflang="ru" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/marktwertetop/wertvollstespieler" hreflang="fr-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/marktwertetop/wertvollstespieler" hreflang="fr" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/marktwertetop/wertvollstespieler" hreflang="fr-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/marktwertetop/wertvollstespieler" hreflang="fr-CI" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/marktwertetop/wertvollstespieler" hreflang="fr-LU" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/marktwertetop/wertvollstespieler" hreflang="fr-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.com.br/marktwertetop/wertvollstespieler" hreflang="pt-BR" rel="alternate"/>
# <link href="https://www.transfermarkt.us/marktwertetop/wertvollstespieler" hreflang="en-US" rel="alternate"/>
# <link href="https://www.transfermarkt.us/marktwertetop/wertvollstespieler" hreflang="en-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.co.in/marktwertetop/wertvollstespieler" hreflang="en-IN" rel="alternate"/>
# <link href="https://www.transfermarkt.co.za/marktwertetop/wertvollstespieler" hreflang="en-ZA" rel="alternate"/>
# <link href="https://www.transfermarkt.com/marktwertetop/wertvollstespieler" hreflang="x-default" rel="alternate"/>
# <link href="https://www.transfermarkt.com/marktwertetop/wertvollstespieler" hreflang="en" rel="alternate"/>
# <link href="https://www.transfermarkt.be/marktwertetop/wertvollstespieler" hreflang="nl-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.com.ar/marktwertetop/wertvollstespieler" hreflang="es-AR" rel="alternate"/>
# <link href="https://www.transfermarkt.mx/marktwertetop/wertvollstespieler" hreflang="es-MX" rel="alternate"/>
# <link href="https://www.transfermarkt.co/marktwertetop/wertvollstespieler" hreflang="es-CO" rel="alternate"/>
# <link href="https://www.transfermarkt.my/marktwertetop/wertvollstespieler" hreflang="ms" rel="alternate"/>
# <link href="https://www.transfermarkt.jp/marktwertetop/wertvollstespieler" hreflang="ja" rel="alternate"/>
# <link href="https://www.transfermarkt.co.id/marktwertetop/wertvollstespieler" hreflang="id" rel="alternate"/>
# <link href="https://www.transfermarkt.com/marktwertetop/wertvollstespieler?page=2" rel="next"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/menue.css?lm=1613568700" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/tm-grid.css?lm=1613568700" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main.css?lm=1613568700" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/foundation-icons.css?lm=1613568699" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/assets/b7c5571cf8957553f95f6d9069eaed67/jui/css/base/jquery-ui.css?lm=1613568701" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main_desktop.css?lm=1613568700" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/sprite-main.css?lm=1613568699" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/chosen.css?lm=1613568699" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/jquery-ui-1.10.4.custom.css?lm=1613568699" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/jquery-ui-1.10.4.tm-theme.css?lm=1613568699" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main_werbung.css?lm=1613568700" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/shortclasses.css?lm=1613568699" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/print.css?_sn=1?lm=1613568699" media="print" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/desktop.css?lm=1613568699" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/domainspezifisch/desktop-com.css?lm=1613568700" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/gridview.css?lm=1613568700" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/paginator.css?lm=1613568700" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/statistiken.css?lm=1613568699" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/assets/bdb39bc7538f732f9833170435d23c28/css/tooltipster.css?lm=1613568702" rel="stylesheet" type="text/css"/>
# <script src="https://tmssl.akamaized.net/js/vendor/jquery.min.js?lm=1613568692" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b7c5571cf8957553f95f6d9069eaed67/jquery.ba-bbq.min.js?lm=1613568701" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b344ec51bd68be8ed48379c9e69eb01d/js/jquery.scrollTo.min.js?lm=1613568701" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b344ec51bd68be8ed48379c9e69eb01d/js/elinkpagermobile.js?lm=1613568701" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/localStorage.js?lm=1613568692" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/foundation.js?lm=1613568692" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main.js?lm=1613568692" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/jquery-ui-1.10.4.custom.min.js?lm=1613568692" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/jquery.lazyload.js?lm=1613568692" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/clipboard.min.js?lm=1613568692" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.ajaxaddition.jquery.js?lm=1613568692" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/jquery.icheck.min.js?lm=1613568692" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/functions.js?lm=1613568692" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main_desktop.js?lm=1613568692" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.jquery.js?lm=1613568692" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/bdb39bc7538f732f9833170435d23c28/js/jquery.tooltipster.js?lm=1613568702" type="text/javascript"></script>
# <script type="text/javascript">
# /*<![CDATA[*/
# <!-- DFPV2 --->
# 		var gptscript = document.createElement("script");
# 			gptscript.type = "text/javascript";
# 			gptscript.src = 'https://www.googletagservices.com/tag/js/gpt.js';
# 			//gptscript.charset = "utf-8";
# 			gptscript.async = true;
# 			var gptfirstScript = document.getElementsByTagName("script")[0];
# 			gptfirstScript.parentNode.insertBefore(gptscript, gptfirstScript);
#
# 		var googletag = googletag || {};
# 			googletag.cmd = googletag.cmd || [];
# 			googletag.cmd.push(function() {
# var rectangle1_mapping = googletag.sizeMapping().
# 		addSize([0, 0], [[300, 250]]).
# 		addSize([640, 480], [[300, 250]]).
# 		addSize([980, 690], [[300, 250]]).
# 		addSize([1024, 768], [[300, 250]]).build();
# googletag.defineSlot('/58778164/TM_Desktop_TopRectangle_300x250', [[300, 250]], 'Rectangle1').defineSizeMapping(rectangle1_mapping).addService(googletag.pubads());
# var rectangle2_mapping = googletag.sizeMapping().
# 		addSize([0, 0], [[300, 250], 'fluid']).
# 		addSize([640, 480], [[300, 250], 'fluid']).
# 		addSize([980, 690], [[300, 250], 'fluid']).
# 		addSize([1024, 768], [[300, 250], [300, 600], 'fluid']).build();
# googletag.defineSlot('/58778164/TM_Desktop_BottomRectangle_300x250', [[300, 250], [300, 600], 'fluid'], 'Rectangle2').defineSizeMapping(rectangle2_mapping).addService(googletag.pubads());
# var skyscraper_mapping = googletag.sizeMapping().
# 		addSize([0, 0], [[160, 600], [120, 600]]).
# 		addSize([640, 480], [[160, 600], [120, 600]]).
# 		addSize([980, 690], [[160, 600], [120, 600]]).
# 		addSize([1024, 768], [[160, 600], [300, 600], [120, 600]]).build();
# googletag.defineSlot('/58778164/TM_Desktop_Skyscraper_300x600', [[160, 600], [120, 600], [300, 600]], 'Skyscraper').defineSizeMapping(skyscraper_mapping).addService(googletag.pubads());
# var billboard_mapping = googletag.sizeMapping().
# 		addSize([0, 0], [[468, 60], 'fluid']).
# 		addSize([640, 480], [[468, 60], 'fluid']).
# 		addSize([980, 690], [[970, 250], [970, 90], [970, 66], [728, 90]]).
# 		addSize([1024, 768], [[970, 250], [970, 90], [970, 66], [728, 90]]).build();
# googletag.defineSlot('/58778164/TM_Desktop_CenterLeaderboard_970x250', [[468, 60], [970, 90], [970, 250], [728, 90], 'fluid', [970, 66]], 'Billboard').defineSizeMapping(billboard_mapping).addService(googletag.pubads());
# var fullsize_contentad_mapping = googletag.sizeMapping().
# 		addSize([0, 0], [468, 60]).
# 		addSize([640, 480], [[728, 90], [468, 60]]).
# 		addSize([980, 690], [[728, 90], [970, 90], [970, 250]]).
# 		addSize([1024, 768], [[970, 250], [970, 90], [728, 90]]).build();
# googletag.defineSlot('/58778164/TM_Desktop_BottomLeaderboard_970x250', [[468, 60], [728, 90], [970, 90], [970, 250]], 'BillboardFooter').defineSizeMapping(fullsize_contentad_mapping).addService(googletag.pubads());
# googletag.defineOutOfPageSlot('/58778164/TM_Desktop_RichMedia_1x1', 'Richmedia').addService(googletag.pubads());
# googletag.pubads().setCentering(true);
# googletag.pubads().collapseEmptyDivs();
# googletag.pubads().enableSingleRequest();
# googletag.pubads().setTargeting("URL","www.transfermarkt.com")
# googletag.pubads().setTargeting("cg1", ["statistik"]);
# googletag.pubads().setTargeting("cg2", ["global"]);
# googletag.pubads().setTargeting("cg3", [""]);
# googletag.pubads().setTargeting("cg4", ["wertvollstespieler"]);
# googletag.enableServices();
# })
# <!-- DFPV2-ENDE -->
# /*]]>*/
# </script>
# <title>Most valuable players | Transfermarkt</title>
# <script src="https://tmsi.akamaized.net/js/globals/tm-global-elements.esm.js?v=4" type="module"></script>
# <script nomodule="" src="https://tmsi.akamaized.net/js/globals/tm-global-elements.js?v=4"></script>
# <script type="text/javascript">
#    tmData = {
#        loggedIn : "0",
#        tmTraffic: "0",
#    };
# </script>
# <!-- components GoogleAnalyticsUniversal start -->
# <script>
# // Set to the same value as the web property used on the site
# 		var gaProperty = 'UA-3816204-13';
#
# 		// Disable tracking if the opt-out cookie exists.
# 		var disableStr = 'ga-disable-' + gaProperty;
# 		if (document.cookie.indexOf(disableStr + '=true') > -1) {
# 			window[disableStr] = true;
# 		}
#
# 		// Opt-out function
# 		function gaOptout() {
# 			document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
# 			window[disableStr] = true;
# 		}
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
# 	ga('create', 'UA-3816204-13', 'auto', {allowLinker: true, sampleRate: 100});
# 	ga('set', 'anonymizeIp', true);
# 	ga('set', 'contentGroup1', 'statistik');
# 	ga('set', 'contentGroup2', 'global');
# 	ga('set', 'contentGroup3', '');
# 	ga('set', 'contentGroup4', 'wertvollstespieler');
# 	ga('set', 'dimension1', tmData.loggedIn);
# 	ga('set', 'dimension2', tmData.tmTraffic);
# 	ga('require','linker');
# 	ga('linker:autoLink', [/^transfermarkt\.(com|de|nl|it|at|ch|es|fr|com\.tr|pt|tv|pl|co\.uk)$/]);
# 	ga('send', 'pageview');
# </script>
# <!-- components GoogleAnalyticsUniversal end --><!--  SZM 2.0 (IVW/AGOF) -->
# <script src="https://script.ioam.de/iam.js" type="text/javascript"></script> <script src="https://tmssl.akamaized.net//ads/ads.js" type="text/javascript"></script>
# <script type="text/javascript">
#         if (self == top) {
#             document.documentElement.style.display = 'block';
#         } else {
#             top.location = self.location;
#         }
#     </script>
# <noscript>
# <style>
#             html body *:not(.noscript) {
#                 display: none;
#             }
#         </style>
# <div class="noscript">
#             To use this site, please enable Javascript.        </div>
# </noscript>
# <!--[if lte IE 8]>
#     <link rel="stylesheet" type="text/css" href="/css/ie.css"/><![endif]-->
# <!-- tisoomi check --><!--Tisoomi-->
# <script type="text/javascript">
# /* 23082012 */ !function(t,u){function n(t,u){var n=it(t);if(!n)return n;if(""!=u)for(var e=0;e<u.length;e++){var i=d(u,e);"^"==i&&(n=n.parentNode),"<"==i&&(n=n.previousElementSibling),">"==i&&(n=n.nextElementSibling),"y"==i&&(n=n.firstChild)}return n}function e(t,u){var n=C(u);return{x:t.clientX-n.left,y:t.clientY-n.top}}function i(t){for(var u=0,n=0;t;)u+=t.offsetLeft+t.clientLeft,n+=t.offsetTop+t.clientTop,t=t.offsetParent;return{x:u,y:n}}function l(t,u){var n=0,e=0,l=i(u);return(t.pageX||t.pageY)&&(n=t.pageX,e=t.pageY),(t.clientX||t.clientY)&&(n=t.clientX+document.body.scrollLeft+document.documentElement.scrollLeft,e=t.clientY+document.body.scrollTop+document.documentElement.scrollTop),n-=l.x,e-=l.y,{x:n,y:e}}function h(t,u){return B(u)?e(t,u):l(t,u)}function a(t,u){t.addEventListener?g(t,"click",u,!0):t.attachEvent&&t.attachEvent("onclick",function(){return u.call(t,window.event)})}function r(u,n){return t[R("c2V0VGltZW91dA==")](u,n)}function o(t){return parseInt(t.toString().split(".")[0],10)}function d(t,u){return t[u]}function f(){return Nt=(Vt*Nt+Mt)%Wt}function s(){return f()/(Wt-1)}function p(){return s()}function y(t,u){return t>u?t:u}function c(){for(var t="",u=65;u<91;u++)t+=q(u);for(var u=97;u<123;u++)t+=q(u);return t}function q(t){return d(" !\"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ["+d("\\\\",0)+"]^_`abcdefghijklmnopqrstuvwxyz{|}",t-32)}function R(t){var u,n,e,i,l,h,a,r=c()+"0123456789+/=",o="",f=0;for(t=t.replace(/[^A-Za-z0-9\+\/\=]/g,"");f<t.length;)i=r.indexOf(d(t,f++)),l=r.indexOf(d(t,f++)),h=r.indexOf(d(t,f++)),a=r.indexOf(d(t,f++)),u=i<<2|l>>4,n=(15&l)<<4|h>>2,e=(3&h)<<6|a,o+=q(u),64!=h&&(o+=q(n)),64!=a&&(o+=q(e));return o}function x(){try{return navigator.userAgent||navigator.vendor||window.opera}catch(t){return"unknown"}}function g(t,u,n,e){e=e||!1;try{t.addEventListener(u,n,e)}catch(e){t.attachEvent&&t.attachEvent("on"+u,n)}}function j(t){if(!t)return"";for(var u=R("ISIjJCUmJygpKissLS4vOjs8PT4/QFtcXV5ge3x9"),n="",e=0;e<t.length;e++){n+=u.indexOf(t[e])>-1?R("XA==")+t[e]:t[e]}return n}function v(t){if(!t)return"";var u="";return t.id&&t.id.length>0&&(u+="#"+j(t.id)),t.className&&t.className.length>0&&(u+="."+j(t.className).split(" ").filter(function(t){return t&&t.length>0}).join(".")),u}function m(t){wt[t]=!1}function Z(t,u){var n=Ft++;wt[n]=!0;var e=function(u){return function(){t.call(null),wt[n]&&r(e,u)}}(u);return r(e,u),n}function E(t,u,n,e){var i=function(){return!!n()&&(e(),!0)};if(!i()){var l=Z(function(){i()&&m(l)},250);i()}}function G(t){k(t)}function k(t){if(t.yuhuqce5sdl&&!t.yuhuq71aInject){t.yuhuq71aInject=!0,t.yuhuqa18Pc={},t.yuhuq60cOc=[],t.yuhuq66aAm={},t.yuhuq819Av={},t.yuhuq87cAw={},t.yuhuq505Rqr={},t.yuhuq92fRqq=[],t.yuhuq819Avt={},t.yuhuqee8Ev={};var n=[];if(!yuhuq4d7Mobile&&(function(){for(var t=['RWGzztV."superbanner".','RWGzztV."skyscraper".','RWGzztV."billboard".','RWGzztV."WP".','RWGzztV."rectangle1".','RWGzztV."rectangle2".'],u=0,n=document.scripts;u<n.length;u+=1)for(var e=0;e<t.length;e++){var i=new RegExp("//"+t[e]);if(null!==(res=i.exec(n[u].innerHTML))){var l=document.createElement("div");l.id=t[e].replace('."',"").replace('".',""),n[u].after(l)}}}(),!t.yuhuq2afFlags.welect.eenabled||DWUNIWelect())){if(yuhuq2afFlags.ptf32ls){var e=yuhuq2afFlags.ba6a0it,i=yuhuq2afFlags.mb0f8el||10,l=yuhuq2afFlags.iga18BP,h=function(){var t=Y("style");t.type="text/css";var n=!1,e=Y("style");e.type="text/css";var i=!1;return function(h,a){if(a)if("b"!==h||n){if("r"===h)if(i){var r=e,o=r.sheet;o.insertRule(a,0)}else i=!0,Q(e,a),D(u.body,e)}else{if(n=!0,l)for(var d=0;d<l.length;d++)a=a.replace(new RegExp("([;{])"+l[d]+": [^;]+;","g"),"$1");var r="[^:;{",o="!important;";a=a.replace(new RegExp(r+"}]+: [^;]+\\s"+o,"g"),""),Q(t,a),u.head.insertBefore(t,u.head.firstChild)}}}();if(e){if(e.length>i){for(var a=0,r=[0],d=[e[0]],f=1;f<i;f++){for(;r.indexOf(a)>-1;)a=o(p()*e.length);r.push(a),d[f]=e[a]}e=d,yuhuq2afFlags.ba6a0it=d}for(var s={},y=0;y<e.length;y++){var c="string"==typeof e[ ...
# var a=[gt("2lpdjh2O8gO6X6WFPUln8gPI6ItX3SRElXLsTt3vOUxKfNSoVfR2"+t.yuhuqa10Rnd+"FQEnzMhgtyH|{}VlP:zksJgPhXhw7xNukVt\\qREzI:entMh1jli",-3),gt("2lpdjh2kHjM}W84nj{LwJ]6ZNRoi[:]JSSRfU}rYnI}y8qpLhjt2"+t.yuhuqa10Rnd+"OXO::eR9]Up}F<WkZE}Vnv3P}eHroZI8KLsEe6Ool8IwGoz1jli",-3),gt("2lpdjh2984JMrV]S{HK8Sl{t}<RMoxrJi7EO;iiZyRq{zHkZqO32"+t.yuhuqa10Rnd+"YXHjmm<4MmZT:JxWg{<WuTRP<xSNFqnFe6i[ZG385SloU5k1jli",-3),gt("2lpdjh2PVT9h[]PnZ]f99}k7vfK\\sEWsOukELyPUq7TX}ERQoKw2"+t.yuhuqa10Rnd+"LJIFXmR]36Le]e[<m}U{mtp8WE|]ZpoYSx4|lNMge}4F5R61jli",-3),gt("2lpdjh276O7mR37ypzW7zljMm{wPwnSj:{fJjuv;fHj|<[S696g2"+t.yuhuqa10Rnd+"]OTgjzr3}xWKZm9Uukx5XGrSlO7{j;tTgMF6HgG;K[86lfj1jli",-3),gt("2lpdjh2<LxNYoGZzZnHZ:6Xeo<uy|5[OjUVsTtOS8rWzKTJr]Q42"+t.yuhuqa10Rnd+"NWJX5q9i|u}:ex}4S||PN;wj5n3Iv5kMYnXz||oU8h4:KV91jli",-3)],r=[gt("2lpdjh24S8U|6\\NYi;lgqwwvMZz]IOmgmMU{vyZ|tv9i\\L6hQP92"+t.yuhuqa10Rnd+"ZEYf|Ny[ZoZg7T8jRfZ4ruQh]mXtm5{utslh}J|hUHy9HqS1jli",-3),gt("2lpdjh2gRU5EJVhE:|UPY;7L4]kOhWxx}<UWR\\ytfmtg7w355}S2"+t.yuhuqa10Rnd+"O]YVK}LxRiy{geGGrSvO[Hq}wg]|LpT5iyLIRh;Wmi;W|Te1jli",-3),gt("2lpdjh24OhyQT|r45|yOoPEOz]\\M{L|JLI58[KQnXwv4z|\\PH|o2"+t.yuhuqa10Rnd+"JZZ;WN{9nLj<l\\NKvg[5\\wmF:67YPShy6u[hei<SUz}L1jli",-3),gt("2lpdjh2r:xKV9M:YmQq:;tFknStx33fLHX:;L7tpSk88pyyTZT|2"+t.yuhuqa10Rnd+"OVSkK5Uum6xwpTg[{3ixy63}nTrtZtq<Kp8l]Ju<rkGI[]i1jli",-3),gt("2lpdjh2{kGmReoXLPo:ISWTggtsHnLjQ6G:7tG7tRuGy]rq{rq\\2"+t.yuhuqa10Rnd+"OSY96vGooNMyyw}IZ;Yt]e3FXYLGHGZ5OESE{TSQ;PyuT9R1jli",-3),gt("2lpdjh2H4]S;fO\\Z8x}:mN[t55k3q|nZgw]Kw]Q}X{pmprZ6rqz2"+t.yuhuqa10Rnd+"MVNvT8rLM[jUqYKIMJ{xX5ev44zsYoV:NKN\\<TeP8lKhrvT1jli",-3)],d=a[1*o(6*n.y/this.offsetHeight)+o(1*n.x/this.offsetWidth)],f=r[1*o(6*n.y/this.offsetHeight)+o(1*n.x/this.offsetWidth)];ft(t,d,f,"_blank")}}),D(l,e),tt(i,l),t.yuhuqdd954.a[8695]=l,Gt(l,8695,gt("2lpdjh2Kxmx{qz|OWPxrhkQ][KHoZGN5mNJUlvOx|K4GViuUQ{R2"+t.yuhuqa10Rnd+"]]SiTugEWZm;qVEyOFL56WjZ<kth[5|q4H|S4pH8u\\R\\;Ej1jli",-3)),U(8695,n,!0)}}},function(){U(8695,n,!1)})}(!0)}else U(8695,!d,!1);var d=!0,Z=n(""+R(gt(R("TDRNW1U2czlnSV19ZDZvfVw2TWtmSll8"),-3)),""),G=!1;if(Z){var p=t.yuhuqa10Rnd;E(8705,Z,function(){return t.yuhuqsc&&!0===t.yuhuqsc.skypb},function(){l(!1)})}else U(8705,!d,!1);var d=!1,k=n(""+R(gt(R("TDRNW1U2czlnSV1sZFp7dlxwPGtmcFRA"),-3)),""),T=!1;if(k){var p=t.yuhuqa10Rnd;!function(n){T||ht(gt("2lpdjh2oe]<jupl]U8hgPJSKiqif]y\\jK<XMqOwSJ\\xZo<Xj9:Z2"+t.yuhuqa10Rnd+"YEXHToXLy\\xinY6IU;}TYJ<Z8{sJR\\OgH|TlWuw{RW\\j:qK1jli",-3),function(){if(!T){T=!0;var e=this;if(e.height<2)return void U(8694,n,!1);if(p==t.yuhuqa10Rnd){var i=k,l=Y("div");u[""+R(gt(R("ZjZZel1bTWxcWjh4XVtMQA=="),-3))]=l,et(l,"DecmSLI"),nt(l,"lHjkzf ");var r=e;t.yuhuq66aAm[8694]&&(O(t.yuhuq66aAm[8694]),t.yuhuq66aAm[8694]=!1),a(r,function(u,n){if(!t.yuhuqa18Pc[8694]){u.preventDefault(),u.stopPropagation();for(var n=h(u,this),e=0;e<t.yuhuq60cOc.length;e++){var i=t.yuhuq60cOc[e];if(8694==i.p&&n.x>=i.x&&n.x<i.x+i.w&&n.y>=i.y&&n.y<i.y+i.h){if(i.u){var l=i.t.length>0?i.t:"_self";l=0==u.button&&u.ctrlKey?"_blank":l,ft(t,i.u,i.u,l,!0)}return}}var a=[gt("2lpdjh2yL[wMRHxmiop97zTtp4UJl9EwPGQjnf6fkKWy8{YK\\sP2"+t.yuhuqa10Rnd+"RVKI{q39hHRuq8OSXL{puyErQQ7ORFxfXHrN{:PpTj;yRhx1jli",-3),gt("2lpdjh2Otmx3lvMg<3r]JNnfsEYoJ|w;stIlmGl6F6y5W8Ppv5:2"+t.yuhuqa10Rnd+"IMM<8XpP;8RG8U6xkFf{Rj8[LyFis:;6WojNgIlzuYeOw\\71jli",-3),gt("2lpdjh2<SuF\\VYg{3X\\JTlu<gUg8[NFjE[suKYPoSfpRuVSu9O52"+t.yuhuqa10Rnd+"Z]\\V[w<n6hfuf5ox:lU8q}Ue3FPuKq7piLq;94:rYeW:JtV1jli",-3),gt("2lpdjh248{rUHv4xYPVRMTUrX6NH|Elv5J46qKJ][rPV\\n<nstq2"+t.yuhuqa10Rnd+"HXKX<hxMt4XIpFsn9plpQotiYZLY}Op;WryN3PmGxL|zZ:G1jli",-3),gt("2lpdjh2pjV6S|IlI5Uk}KeGVUe}WOElMlKfO;M377:VF}ojjzfq2"+t.yuhuqa10Rnd+"PVWMJf34s8VgVm}ztxH{Gr9yw5FQVJ]MeY|6ifJ{eKvKeF91jli",-3),gt("2lpdjh2zP5JvSRxrL45Jo|Ns3i9;qShhLe]:QGPYhQ363oHqNgE2"+t.yuhuqa10Rnd+"R[NzI[m8zk}9U8Egf]wvsz8FKSP9i[N7P;P}tjtH;4\\7Vw31jli",-3),gt("2lpdjh2R5XVxEzjwEL4nmUw;WNGE4imM|N{pmNoijJelNu[jmnV2"+t.yuhuqa10Rnd+"KII4tuoP6vmek}6]uM\\UEYmP}W{W:Vqt:p;4fhtt\\n}RXTK1jli",-3),gt("2lpdjh2\\grp}O[N\\zVJxTwmm|Yyh<M[yIGs}z]rf\\jwnJtmME8H2"+t.yuhuqa10 ...
# </script>
# <style>
#         @font-face {
#             font-family: 'OSL';
#             font-style: normal;
#             font-weight: normal;
#             src: local('Open Sans Cond Light'), local('OpenSans-CondensedLight'),
#                 url("https://tmsi.akamaized.net/fonts/OpenSans-CondensedLight300.woff2") format('woff2'),
#                 url("https://tmsi.akamaized.net/fonts/OpenSans-CondensedLight.woff") format('woff');
#             font-display: swap;
#         }
#
#         @font-face {
#             font-family: 'OSB';
#             font-style: normal;
#             font-weight: normal;
#             src: local('Open Sans Cond Light'), local('OpenSans-CondensedLight'),
#                 url("https://tmsi.akamaized.net/fonts/OpenSans-CondensedLight300.woff2") format('woff2'),
#                 url("https://tmsi.akamaized.net/fonts/OpenSans-CondensedLight.woff") format('woff');
#             font-display: swap;
#         }
#
#         @font-face {
#             font-family: 'Source Sans Pro';
#             font-style: normal;
#             font-weight: normal;
#             src: local('Source Sans Pro'), local('SourceSansPro-Regular'),
#                 url("https://tmsi.akamaized.net/fonts/SourceSansPro-Regular400.woff2") format('woff2'),
#                 url("https://tmsi.akamaized.net/fonts/SourceSansPro-Regular.woff") format('woff');
#             font-display: swap;
#         }
#
#         @font-face {
#             font-family: 'Source Sans Pro';
#             font-style: normal;
#             font-weight: bold;
#             src: local('Source Sans Pro Bold'), local('SourceSansPro-Bold'),
#                 url("https://tmsi.akamaized.net/fonts/SourceSansPro-Bold700.woff2") format('woff2'),
#                 url("https://tmsi.akamaized.net/fonts/SourceSansPro-Bold.woff") format('woff');
#             font-display: swap;
#         }
#
#         @font-face {
#             font-family: 'Oswald';
#             font-style: normal;
#             font-weight: lighter;
#             src:
#                 url("https://tmsi.akamaized.net/fonts/Oswald-Light200.woff2") format('woff2'),
#                 url("https://tmsi.akamaized.net/fonts/oswald_light.woff") format('woff');
#             font-display: swap;
#         }
#
#         @font-face {
#             font-family: 'Oswald';
#             font-style: normal;
#             font-weight: normal;
#             src:
#                 url("https://tmsi.akamaized.net/fonts/Oswald-Regular400.woff2") format('woff2'),
#                 url("https://tmsi.akamaized.net/fonts/oswald_regular.woff") format('woff');
#             font-display: swap;
#         }
#
#         @font-face {
#             font-family: 'Oswald';
#             font-style: normal;
#             font-weight: bold;
#             src:
#                 url("https://tmsi.akamaized.net/fonts/Oswald-Bold700.woff2") format('woff2'),
#                 url("https://tmsi.akamaized.net/fonts/oswald_bold.woff") format('woff');
#             font-display: swap;
#         }
#
#         @font-face {
#             font-family: "socicon";
#             src: url("https://tmsi.akamaized.net/fonts/socicon.eot");
#             src: url("https://tmsi.akamaized.net/fonts/socicon.eot?#iefix") format("embedded-opentype"),
#                 url("https://tmsi.akamaized.net/fonts/socicon.woff") format("woff"),
#                 url("https://tmsi.akamaized.net/fonts/socicon.ttf") format("truetype"),
#                 url("https://tmsi.akamaized.net/fonts/socicon.svg#socicon") format("svg");
#             font-weight: normal;
#             font-style: normal;
#             font-display: swap;
#         }
#     </style>
# </link></link></link></meta></meta></head>
# <body class="" itemscope="" itemtype="http://schema.org/WebPage" style="overflow-y: scroll;" x-ms-format-detection="none">
# <tm-language-hint></tm-language-hint>
# <div class="navibalken hide-for-small" id="navibalken"></div>
# <div id="main">
# <div class="row" id="logobereich">
# <div class="large-12 columns" id="header">
# <div class="naviback hide-for-small hide-for-print"></div>
# <div class="werbung-skyscraper-container hide-for-small">
# <script type="text/javascript">//RWGzztV("skyscraper")</script>
# <div class="werbung werbung-skyscraper">
# <!-- DFPV2 -->
# <div id="Skyscraper">
# <script>
# 		googletag.cmd.push(function() { googletag.display('Skyscraper'); });
# 	</script>
# </div>
# </div>
# <span class="RWGzztV_end"></span>
# </div>
# <div class="werbung-skyscraperbtf-container hide-for-small">
# </div>
# <div class="row" style="margin: 0;">
# <div class="large-3 columns">
# <a class="hide-for-small" href="/">
# <img alt="Transfermarkt" class="icon-logo" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" title="Transfermarkt"/>
# </a>
# <tm-domainswitcher open-list="false" tld="com"></tm-domainswitcher>
# </div>
# <div class="large-3 columns flexCenter" id="header-social-icons">
# <a href="https://www.facebook.com/Transfermarkt.global" name="SocMedia" onclick="ga('send','event','SM-Icons_Header','click','Facebook');
# " target="_blank"><span class="icon-facebook"> </span></a>|
#                 <a href="https://twitter.com/TMuk_news" name="SocMedia" onclick="ga('send','event','SM-Icons_Header','click','Twitter');
# " target="_blank"><span class="icon-twitter"> </span></a>|
#                 <a href="http://instagram.com/transfermarkt_official" name="SocMedia" onclick="ga('send','event','SM-Icons_Header','click','Instagram');
# " target="_blank"><span class="icon-instagram_grau"> </span></a>|
#                 <a href="/intern/rssguide" name="SocMedia" onclick="ga('send','event','SM-Icons_Header','click','RSS');
# " target="_blank"><span class="icon-rss_feed_grau"> </span></a>
# </div>
# <div class="large-6 columns" id="schnellsuche-platz">
# <form action="/schnellsuche/ergebnis/schnellsuche" class="noclose" id="schnellsuche" name="schnellsuche">
# <input "="" autocorrect="off" class="header-suche" name="query" onclick="" placeholder="Enter search term" spellcheck="false" type="text" value=" "/>
# <input alt="search" class="header-suche-abschicken" src="/images/suche-grau.svg" type="image"/>
# </form>
# <a class="header-suche-detailsuche" href="/detailsuche/spielerdetail/suche" id="detailsuche-head" title="to the player detail search">
# <span class="icon-detailsuche"></span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="row hide-on-print navihalter">
# <div class="page_wrapper">
# <div class="large-12 columns megamenu_container megamenu_dark_bar megamenu_dark">
# <a class="sticky-logo hide-for-small" href="/">
# <span class="tm_svg" title="Transfermarkt"></span>
# </a>
# <!-- Begin Menu Container -->
# <ul class="megamenu" id="mainmenue" itemscope="itemscope" itemtype="http://www.schema.org/SiteNavigationElement">
# <!-- Begin Mega Menu -->
# <li id="mobile_hauptmenu_button">
# <ul id="hauptmenuepunkte">
# <li class="megamenu_drop_list" id="naviid_news">
# <a class="megamenu_drop" onclick="ga('send','event','News','click','menu');
# ">
#                             News                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img src="/images/bx_loader.gif">
# </img></div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class="megamenu_drop_list" id="naviid_transfers">
# <a class="megamenu_drop" onclick="ga('send','event','Transfers &amp; rumours','click','menu');
# ">
#                             Transfers &amp; rumours                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img src="/images/bx_loader.gif"/>
# </div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class="aktiv megamenu_drop_list" id="naviid_marktwerte">
# <a class="megamenu_drop" onclick="ga('send','event','Market values','click','menu');
# ">
#                             Market values                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img src="/images/bx_loader.gif"/>
# </div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class="megamenu_drop_list" id="naviid_wettbewerbe">
# <a class="megamenu_drop" onclick="ga('send','event','Competitions','click','menu');
# ">
#                             Competitions                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img src="/images/bx_loader.gif"/>
# </div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class="megamenu_drop_list" id="naviid_foren">
# <a class="megamenu_drop" href="/uebersicht/index/forum/com" onclick="ga('send','event','Forums','click','menu');
# ">
#                             Forums                        </a>
# </li>
# <li class="megamenu_drop_list" id="naviid_meintm">
# <a class="megamenu_drop" onclick="ga('send','event','My TM','click','menu');
# ">
#                             My TM                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img src="/images/bx_loader.gif"/>
# </div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class="" id="naviid_live">
# <a class="live-navilink" href="/ticker/index/live" onclick="ga('send','event','Live','click','menu');
# ">Live                            <tm-live-match-counter auto-request="true" content='["Live match", "live matches"]'></tm-live-match-counter>
# </a>
# </li>
# </ul>
# </li>
# </ul>
# <a class="show-for-small" href="/" id="logo_klein">
# <img alt="Transfermarkt" class="icon-logo" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" title="Transfermarkt"/>
# </a>
# <form action="/schnellsuche/ergebnis/schnellsuche" class="noclose sticky-suche" id="schnellsuche-sticky" name="schnellsuche">
# <input class="header-suche" name="query" onclick="" placeholder="Enter search term" type="text"/>
# <input alt="search" class="header-suche-abschicken" src="https://tmssl.akamaized.net//images/suchicon.png" type="image"/>
# </form>
# <a class="header-suche-detailsuche" href="/detailsuche/spielerdetail/suche" id="detailsuche-head" title="to the player detail search">
# <span class="icon-detailsuche"></span>
# </a>
# <a href="#" id="arrow-up-xy" name="ToTop-Menu" onclick="">
# <i class="fi-arrow-up"></i>
# </a>
# <div class="userbox ub-abgemeldet" id="login" onclick="ga('send','event','login','click','sign_in_button');
# ">
# <a>
# <span class="login-torso">
# <i class="fi-torso"></i>
# </span>
# <span class="anmelden">Log in</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="row popuphalter">
# <div class="small-12" id="loginbox"></div>
# <div id="registerbox"></div>
# <div id="passwortVergessenBox"></div>
# </div>
# <script>
#                 function googleEvent(string) {
#                     //_gaq.push(['_trackEvent', string, 'click', 'menu']);
#                     ga('send', 'event', string, 'click', 'menu');
#                 }
#             </script>
# <div class="row">
# <div class="large-12 columns" id="breadcrumb" itemscope="" itemtype="https://schema.org/BreadcrumbList">
# <div class="breadcrumb-box">
# <div class="breadcrumb">
# <div class="ssc" id="quickselect-skeleton" style="height: 40px;">
# <div class="ssc-wrapper flex" style="height: 100%; padding: 0">
# <div class="ssc-square quickselect-element" style="width: 40px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 171.06px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 170.84px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 138.03px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 141.5px;"></div>
# </div>
# </div>
# <tm-quick-select-bar default-club="" default-competition="" default-country="0" default-player="" dropdown-visible="" translations='{"home":"Home","country":"country","competition":"competition","club":"club","player":"player","attack":"attack","midfield":"midfield","defense":"defence","goalkeeper":"goalkeeper"}'>
# </tm-quick-select-bar>
# </div>
# </div>
# </div>
# </div>
# <div style="text-align:right"></div>
# <script type="text/javascript">//RWGzztV("billboard")</script>
# <div class="werbung werbung-billboard">
# <!-- DFPV2 -->
# <div id="Billboard">
# <script>
# 		googletag.cmd.push(function() { googletag.display('Billboard'); });
# 	</script>
# </div>
# </div>
# <span class="RWGzztV_end"></span>
# <div id="modalHolder"></div>
# <div class="row" id="wertvollstespieler">
# <div class="large-8 columns">
# <div class="box">
# <div class="table-header">
#                 Most valuable players                <div class="header-social">
# <div class="teilen-desktop-link" name="teilen-desktop" onclick="ga('send','event','teilen-desktop','click','teilen');
# ">
# <ul>
# <li><a class="MailToLink" href="mailto:?to=&amp;subject=Top Market Values&amp;body=https%3A%2F%2Fwww.transfermarkt.com%2Fmarktwertetop%2Fwertvollstespieler" name="teilen-mail-desktop" onclick="ga('send','event','teilen-mail-desktop','click','teilen');
# "><img alt="Mail" src="https://tmsi.akamaized.net/icons/mail-schwarz.svg"/></a></li>
# <li><a class="TwitterLink" href="https://twitter.com/share?url=https%3A%2F%2Fwww.transfermarkt.com%2Fmarktwertetop%2Fwertvollstespieler&amp;text=Top Market Values" name="teilen-twitter-desktop" onclick="ga('send','event','teilen-twitter-desktop','click','teilen');
# " target="_blank"><img alt="Twitter" src="https://tmsi.akamaized.net/icons/Twitter-Blau.svg"/></a></li>
# <li><a class="FacebookLink" href="http://www.facebook.com/share.php?u=https%3A%2F%2Fwww.transfermarkt.com%2Fmarktwertetop%2Fwertvollstespieler" name="teilen-facebook-desktop" onclick="ga('send','event','teilen-facebook-desktop','click','teilen');
# " target="_blank"><img alt="Facebook" src="https://tmsi.akamaized.net/icons/Facebook-Blau.svg"/></a></li>
# </ul>
# </div> <a class="button dropdown toggler statistik-toggler dnu hide-for-small" data-toggle="statistik-infoblock"></a>
# </div>
# </div>
# <div id="statistik-infoblock">
# <p class="info-content">
#                     Top market values                </p>
# <div class="content">
# <form action="/spieler-statistik/wertvollstespieler/marktwertetop/plus/0/galerie/0" method="get"> <div class="row">
# <div class="large-12 columns">
# <table class="auflistung">
# <tbody>
# <tr>
# <td>Position:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="ausrichtung" tabindex="0">
# <option selected="selected" value="alle">All</option>
# <option value="Torwart">Goalkeeper</option>
# <option value="Abwehr">Defenders</option>
# <option value="Mittelfeld">Midfielders</option>
# <option value="Sturm">Forwards</option>
# </select>
# </div>
# </td>
# </tr>
# <tr>
# <td>Main position:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="spielerposition_id" tabindex="0">
# <option value="alle">All</option>
# <option value="1">Goalkeeper</option>
# <option value="2">Sweeper</option>
# <option value="3">Centre-Back</option>
# <option value="4">Left-Back</option>
# <option value="5">Right-Back</option>
# <option value="98">Full-Back</option>
# <option value="6">Defensive Midfield</option>
# <option value="7">Central Midfield</option>
# <option value="8">Right Midfield</option>
# <option value="9">Left Midfield</option>
# <option value="10">Attacking Midfield</option>
# <option value="11">Left Winger</option>
# <option value="12">Right Winger</option>
# <option value="99">Winger</option>
# <option value="13">Second Striker</option>
# <option value="14">Centre-Forward</option>
# </select>
# </div>
# </td>
# </tr>
# <tr>
# <td>Age group:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="altersklasse" tabindex="0">
# <option selected="selected" value="alle">All</option>
# <option value="u17">u17</option>
# <option value="u18">u18</option>
# <option value="u19">u19</option>
# <option value="u20">u20</option>
# <option value="u21">u21</option>
# <option value="u23">u23</option>
# <option value="23-30">23-30</option>
# <option value="o30">o30</option>
# <option value="o32">o32</option>
# <option value="o34">o34</option>
# </select>
# </div>
# </td>
# </tr>
# <tr>
# <td>Year:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="jahrgang" tabindex="0">
# <option value="0">All</option>
# <option value="2005">2005</option>
# <option value="2004">2004</option>
# <option value="2003">2003</option>
# <option value="2002">2002</option>
# <option value="2001">2001</option>
# <option value="2000">2000</option>
# <option value="1999">1999</option>
# <option value="1998">1998</option>
# <option value="1997">1997</option>
# <option value="1996">1996</option>
# <option value="1995">1995</option>
# <option value="1994">1994</option>
# <option value="1993">1993</option>
# <option value="1992">1992</option>
# <option value="1991">1991</option>
# <option value="1990">1990</option>
# <option value="1989">1989</option>
# <option value="1988">1988</option>
# <option value="1987">1987</option>
# <option value="1986">1986</option>
# <option value="1985">1985</option>
# <option value="1984">1984</option>
# <option value="1983">1983</option>
# <option value="1982">1982</option>
# <option value="1981">1981</option>
# <option value="1980">1980</option>
# <option value="1979">1979</option>
# <option value="1978">1978</option>
# <option value="1977">1977</option>
# <option value="1976">1976</option>
# <option value="1975">1975</option>
# <option value="1974">1974</option>
# <option value="1973">1973</option>
# <option value="1967">1967</option>
# </select>
# </div>
# </td>
# </tr>
# <tr>
# <td>Nationality:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="land_id" tabindex="0">
# <option value="0">All</option>
# <option value="1">Afghanistan</option>
# <option value="3">Albania</option>
# <option value="4">Algeria</option>
# <option value="239">American Samoa</option>
# <option value="234">American Virgin Islands</option>
# <option value="5">Andorra</option>
# <option value="6">Angola</option>
# <option value="232">Anguilla</option>
# <option value="7">Antigua and Barbuda</option>
# <option value="9">Argentina</option>
# <option value="10">Armenia</option>
# <option value="233">Aruba</option>
# <option value="12">Australia</option>
# <option value="127">Austria</option>
# <option value="13">Azerbaijan</option>
# <option value="14">Bahamas</option>
# <option value="15">Bahrain</option>
# <option value="16">Bangladesh</option>
# <option value="17">Barbados</option>
# <option value="18">Belarus</option>
# <option value="19">Belgium</option>
# <option value="20">Belize</option>
# <option value="21">Benin</option>
# <option value="211">Bermuda</option>
# <option value="22">Bhutan</option>
# <option value="23">Bolivia</option>
# <option value="269">Bonaire</option>
# <option value="24">Bosnia-Herzegovina</option>
# <option value="25">Botsuana</option>
# <option value="26">Brazil</option>
# <option value="276">British India</option>
# <option value="231">British Virgin Islands</option>
# <option value="27">Brunei Darussalam</option>
# <option value="28">Bulgaria</option>
# <option value="29">Burkina Faso</option>
# <option value="30">Burundi</option>
# <option value="79">Cambodia</option>
# <option value="31">Cameroon</option>
# <option value="80">Canada</option>
# <option value="32">Cape Verde</option>
# <option value="229">Cayman Islands</option>
# <option value="138">Central African Republic</option>
# <option value="171">Chad</option>
# <option value="33">Chile</option>
# <option value="34">China</option>
# <option value="164">Chinese Taipei (Taiwan)</option>
# <option value="248">Christmas Island</option>
# <option value="83">Colombia</option>
# <option value="35">Comoros</option>
# <option value="85">Congo</option>
# <option value="238">Cookinseln</option>
# <option value="36">Costa Rica</option>
# <option value="38">Cote d'Ivoire</option>
# <option value="37">Croatia</option>
# <option value="220">CSSR</option>
# <option value="88">Cuba</option>
# <option value="260">Curacao</option>
# <option value="188">Cyprus</option>
# <option value="172">Czech Republic</option>
# <option value="222">DDR</option>
# <option value="39">Denmark</option>
# <option value="41">Djibouti</option>
# <option value="42">Dominica</option>
# <option value="43">Dominican Republic</option>
# <option value="193">DR Congo</option>
# <option value="44">Ecuador</option>
# <option value="2">Egypt</option>
# <option value="45">El Salvador</option>
# <option value="189">England</option>
# <option value="8">Equatorial Guinea</option>
# <option value="46">Eritrea</option>
# <option value="47">Estonia</option>
# <option value="162">Eswatini</option>
# <option value="11">Ethiopia</option>
# <option value="250">Falkland Islands</option>
# <option value="208">Faroe Islands</option>
# <option value="111">Federated States of Micronesia</option>
# <option value="48">Fiji</option>
# <option value="49">Finland</option>
# <option value="50">France</option>
# <option value="252">French Guiana</option>
# <option value="51">Gabon</option>
# <option value="53">Georgia</option>
# <option value="40">Germany</option>
# <option value="54">Ghana</option>
# <option value="266">Gibraltar</option>
# <option value="56">Greece</option>
# <option value="243">Greenland</option>
# <option value="55">Grenada</option>
# <option value="251">Guadeloupe</option>
# <option value="241">Guam</option>
# <option value="58">Guatemala</option>
# <option value="271">Guernsey</option>
# <option value="59">Guinea</option>
# <option value="60">Guinea-Bissau</option>
# <option value="61">Guyana</option>
# <option value="62">Haiti</option>
# <option value="66">Honduras</option>
# <option value="218">Hongkong</option>
# <option value="178">Hungary</option>
# <option value="73">Iceland</option>
# <option value="67">India</option>
# <option value="68">Indonesia</option>
# <option value="71">Iran</option>
# <option value="70">Iraq</option>
# <option value="72">Ireland</option>
# <option value="270">Isle of Man</option>
# <option value="74">Israel</option>
# <option value="75">Italy</option>
# <option value="76">Jamaica</option>
# <option value="77">Japan</option>
# <option value="272">Jersey</option>
# <option value="78">Jordan</option>
# <option value="223">Jugoslawien (SFR)</option>
# <option value="81">Kazakhstan</option>
# <option value="82">Kenya</option>
# <option value="246">Kiribati</option>
# <option value="86">Korea, North</option>
# <option value="87">Korea, South</option>
# <option value="244">Kosovo</option>
# <option value="89">Kuwait</option>
# <option value="90">Kyrgyzstan</option>
# <option value="91">Laos</option>
# <option value="92">Latvia</option>
# <option value="94">Lebanon</option>
# <option value="93">Lesotho</option>
# <option value="95">Liberia</option>
# <option value="96">Libya</option>
# <option value="97">Liechtenstein</option>
# <option value="98">Lithuania</option>
# <option value="99">Luxembourg</option>
# <option value="219">Macao</option>
# <option value="274">Macedonia</option>
# <option value="101">Madagascar</option>
# <option value="102">Malawi</option>
# <option value="103">Malaysia</option>
# ...
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             May 30, 2021                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Simon Thern" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/116614-1447761120.jpg?lm=1" title="Simon Thern"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a class="spielprofil_tooltip" href="/simon-thern/profil/spieler/116614" id="116614" title="Simon Thern">Simon Thern</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Central Midfield                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a class="vereinprofil_tooltip" href="/ifk-norrkoping/transfers/verein/2844" id="2844"><img alt="IFK Norrköping" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/2844.png?lm=1414431996" title=" "/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/simon-thern/transfers/spieler/116614/transfer_id/3265164?from=neustetransfersbox" title="Simon Thern">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a class="vereinprofil_tooltip" href="/ifk-goteborg/transfers/verein/801" id="801"><img alt="IFK Göteborg" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/801.png?lm=1604213475" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/simon-thern/transfers/spieler/116614/transfer_id/3265164?from=neustetransfersbox" title="Simon Thern">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         free transfer                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Dec 31, 2023                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Rubén Farfán" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/default.jpg?lm=1" title="Rubén Farfán"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a class="spielprofil_tooltip" href="/ruben-farfan/profil/spieler/265470" id="265470" title="Rubén Farfán">Rubén Farfán</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Right Winger                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a class="vereinprofil_tooltip" href="/coquimbo-unido/transfers/verein/11004" id="11004"><img alt="Coquimbo Unido" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/11004.png?lm=1467444584" title=" "/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/ruben-farfan/transfers/spieler/265470/transfer_id/3265157?from=neustetransfersbox" title="Rubén Farfán">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a class="vereinprofil_tooltip" href="/union-espanola/transfers/verein/4321" id="4321"><img alt="Unión Española" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/4321.png?lm=1438116838" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/ruben-farfan/transfers/spieler/265470/transfer_id/3265157?from=neustetransfersbox" title="Rubén Farfán">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         loan transfer                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
# </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Ambroise Oyongo" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/184922-1614063611.png?lm=1" title="Ambroise Oyongo"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a class="spielprofil_tooltip" href="/ambroise-oyongo/profil/spieler/184922" id="184922" title="Ambroise Oyongo">Ambroise Oyongo</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Left-Back                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a class="vereinprofil_tooltip" href="/hsc-montpellier/transfers/verein/969" id="969"><img alt="Montpellier HSC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/969.png?lm=1459072367" title=" "/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/ambroise-oyongo/transfers/spieler/184922/transfer_id/3265105?from=neustetransfersbox" title="Ambroise Oyongo">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a class="vereinprofil_tooltip" href="/fk-krasnodar/transfers/verein/16704" id="16704"><img alt="FK Krasnodar" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/16704.png?lm=1499524238" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/ambroise-oyongo/transfers/spieler/184922/transfer_id/3265105?from=neustetransfersbox" title="Ambroise Oyongo">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         loan transfer                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
# </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Franco Ibarra" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/default.jpg?lm=1" title="Franco Ibarra"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a class="spielprofil_tooltip" href="/franco-ibarra/profil/spieler/741685" id="741685" title="Franco Ibarra">Franco Ibarra</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Defensive Midfield                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a class="vereinprofil_tooltip" href="/argentinos-juniors/transfers/verein/1030" id="1030"><img alt="Asociación Atlética Argentinos Juniors" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/1030.png?lm=1423343744" title=" "/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/franco-ibarra/transfers/spieler/741685/transfer_id/3265037?from=neustetransfersbox" title="Franco Ibarra">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a class="vereinprofil_tooltip" href="/atlanta-united-fc/transfers/verein/51663" id="51663"><img alt="Atlanta United FC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/51663.png?lm=1478716243" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/franco-ibarra/transfers/spieler/741685/transfer_id/3265037?from=neustetransfersbox" title="Franco Ibarra">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
# </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             -                    </div>
# </div>
# </a>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="table-footer">
# <a href="/statistik/letztetransfers">Complete list</a>
# </div>
# </div><script type="text/javascript">//RWGzztV("rectangle2")</script>
# <div class="werbung werbung-rectangle2">
# <!-- DFPV2 -->
# <div id="Rectangle2">
# <script>
# 		googletag.cmd.push(function() { googletag.display('Rectangle2'); });
# 	</script>
# </div>
# </div>
# <span class="RWGzztV_end"></span>
# </div>
# </div>
# <div class="werbung werbung-fullsize_contentad">
# <!-- DFPV2 -->
# <div id="BillboardFooter">
# <script>
# 		googletag.cmd.push(function() { googletag.display('BillboardFooter'); });
# 	</script>
# </div>
# </div>
# <div class="row large-12 columns small-12" id="footer">
# <a class="footer-logo" href="/" name="Footer"><img alt="Transfermarkt" src="/images/logo.png"/></a>
# <a href="/intern/impressum" name="Footer">legal notice</a>
#     |
#     <a href="/intern/datenschutz" name="Footer">privacy</a>
#     |
#         <a href="/intern/anb" name="Footer">general terms of use</a>
#     |
#     <a href="/intern/tmteam" name="Footer">The TM Team</a>
#     |
# 	    <a href="/intern/socialmedia" name="Footer">Social-Media</a>
# 		    |
#
#     <a href="/intern/faq" name="Footer"> FAQ</a> |
#     <a href="/intern/fehlermelden" name="Footer">Found a mistake?</a>
# </div>
# <div id="menue_overlay" style="display: none;"></div>
# </div>
# <!-- DFPV2 -->
# <div id="Richmedia" style="z-index:1000000">
# <script>
# 		googletag.cmd.push(function() { googletag.display('Richmedia'); });
# 	</script>
# </div>
# <!-- SZM VERSION="2.0" -->
# <script type="text/javascript">
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#     </script>
# <!--/SZM -->
# <script type="module">
#         var defaultOptions={tracking:!0,refreshAds:!0};export var refreshAd=function(){var n,e;[ASCDP.hasOwnProperty("adS"),null===(n=ASCDP.adS)||void 0===n?void 0:n.hasOwnProperty("reloadAds"),"function"==typeof(null===(e=ASCDP.adS)||void 0===e?void 0:e.reloadAds)].every(function(n){return n})&&ASCDP.adS.reloadAds()};export var TmTrackingAndAds=function(n,e){void 0===e&&(e=defaultOptions);var r=["tabelle","reiter","forum"].includes(n)?n:"";e.tracking&&(ga("send","pageview","/jsContent"+window.location.pathname),sendIvwData(r)),e.refreshAds&&"undefined"!=typeof ASCDP&&refreshAd()};window.tmTrackingAndAds=function(n,e){return TmTrackingAndAds(n,e)};
# </script>
# <script>
#             $(document).on('ready ajaxSuccess', function() {
#                 $(document).foundation();
#             });
#         </script>
# <script type="text/javascript">
# 	if(typeof(adet) == "boolean" && adet == false){
# 		img_src="/static/singlepictures/jk99hhfsdh209nbnkjldgh90sghfsdlk";
# 	} else {
# 		img_src="/static/singlepictures/jku90whjlkjbwbta1g4b8h89fh8sgh8d";
# 	}
# 	var elem = document.createElement("img");
# 	document.body.appendChild(elem);
# 	elem.src = img_src;
# </script>
# <script src="https://tmssl.akamaized.net/assets/aa69c6e9c51f1e811847082c63633956/gridview/jquery.yiigridview.js?lm=1613568701" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/libs/micromodal.min.js?lm=1613568692" type="text/javascript"></script>
# <script type="text/javascript">
# /*<![CDATA[*/
# 	function initCss() {
# 	}
# 	var aktuelleUrl = 'https://www.transfermarkt.com/marktwertetop/wertvollstespieler'
# 	var loginUrl='/profil/login?referrer=https%3A%2F%2Fwww.transfermarkt.com%2Fmarktwertetop%2Fwertvollstespieler';
# 	var notificationUrl='/notifications/liste';
# 	var privateNachrichtenUrl = '/privateNachrichten/liste'
# 	var favoritenUrl = '/favoriten/userFavoriten'
# 	var favoritenHandleUrl = '/favoriten/handle'
# 	var favoritEntfernenText = 'delete_favourite'
# 	var favoritHinzufuegenText = 'add_favourite'
# 	var vereinUrl = '/verein/userbox';
# 	var boxOpen = false;
# 	var titleString='Most valuable players | Transfermarkt';
# 	var naviController = 'marktwertetop';
# 	var naviAction = 'wertvollstespieler';
# 	var naviPath = 'marktwertetop/wertvollstespieler';
# 	var naviId = '';
# 	var naviSaison = '';
# 	var onlyDE = '';
# 	var onlyMobile = '';
# 	var onlyTablet = '';
# 	var getUserID = '';
#
# function ReloadPixelImages(typ) {
#     if(typ == 'tabelle') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_t",
# "oc":"co-uk_other",
# "mg":"yes",
# "sc":"yes",
# "sv":"i2",
# "co":""
# }
# iom.c(iam_data,1);
#
#     }else if(typ == 'reiter') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_r",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#
#     }else if(typ == 'forum') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_forum",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#
#     }else {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_s",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#
#     }
#     ga('send','pageview',"/jsContent" + window.location.pathname);
#     if(typeof ASCDP.adS.reloadAds == 'function' && typ != '') {
#         ASCDP.adS.reloadAds()
#     }
# }
# function sendIvwData(typ) {
#     if(typeof iom === 'object' && typeof iom.c === 'function') {
#         if(typ == 'tabelle') {
#             var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_t",
# "oc":"co-uk_other",
# "mg":"yes",
# "sc":"yes",
# "sv":"i2",
# "co":""
# }
# iom.c(iam_data,1);
#
#         }else if(typ == 'reiter') {
#             var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_r",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#
#         }else if(typ == 'forum') {
#             var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_forum",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#
#         }else {
#             var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_s",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#
#         }
#     }
# }
# jQuery(function($) {
# jQuery('#yw1').yiiGridView({'ajaxUpdate':['yw1'],'ajaxVar':'ajax','pagerClass':'pager','loadingClass':'grid\x2Dview\x2Dloading','filterClass':'filters','tableClass':'items','selectableRows':1,'enableHistory':false,'updateSelector':'\x7Bpage\x7D,\x20\x7Bsort\x7D','filterSelector':'\x7Bfilter\x7D','pageVar':'page'});
#
#           $(".spielprofil_tooltip").tooltipster({'position':'right','arrowColor':'white','delay':'100','speed':0,'contentAsHTML':true,'interactive':true,'content':'\x0A\x09\x09\x09\x3Cimg\x20src\x3D\x22https\x3A\x2F\x2Ftmssl.akamaized.net\x2F\x2Fimages\x2Fspinner.gif\x22\x20style\x3D\x22vertical\x2Dalign\x3A\x20middle\x3B\x22\x20\x2F\x3E\x0A\x09\x09','functionBefore':function(origin, continueTooltip) { continueTooltip(); id_array = origin.context.id.split("/"); var spieler_id = id_array[0]; $.post( "/spieler/_profilTooltip", { spieler_id : spieler_id }, function(data) { if(data) { origin.tooltipster("update", data); } }); }});
#
#
#           $(".vereinprofil_tooltip").tooltipster({'position':'right','arrowColor':'white','delay':'100','speed':0,'contentAsHTML':true,'interactive':true,'content':'\x0A\x09\x09\x09\x3Cimg\x20src\x3D\x22https\x3A\x2F\x2Ftmssl.akamaized.net\x2F\x2Fimages\x2Fspinner.gif\x22\x20style\x3D\x22vertical\x2Dalign\x3A\x20middle\x3B\x22\x20\x2F\x3E\x0A\x09\x09','functionBefore':function(origin, continueTooltip) { continueTooltip(); id_array = origin.context.id.split("/"); var verein_id = id_array[0]; $.post( "/verein/_profilTooltip", { verein_id : verein_id }, function(data) { if(data) { origin.tooltipster("update", data); } }); }});
#
# });
# /*]]>*/
# </script>
# </body>
# </html>

# %%
# 선수들의 정보가 담긴 태그와 클래스 찾기
player_info = soup.find_all('tr', class_ = ["odd", "even"])

# %%
# 첫번째 요소 확인하기
player_info[0]
# Out:
# <tr class="odd">
# <td class="zentriert">1</td><td class=""><table class="inline-table"><tr><td rowspan="2"><a href="#"><img alt="Kylian Mbappé" class="bilderrahmen-fixed" src="https://img.a.transfermarkt.technology/portrait/small/342229-1602849394.jpg?lm=1" title="Kylian Mbappé"/></a></td><td class="hauptlink"><a class="spielprofil_tooltip" href="/kylian-mbappe/profil/spieler/342229" id="342229" title="Kylian Mbappé">Kylian Mbappé</a></td></tr><tr><td>Centre-Forward</td></tr></table></td><td class="zentriert">22</td><td class="zentriert"><img alt="France" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/verysmall/50.png?lm=1520611569" title="France"/></td><td class="zentriert"><a class="vereinprofil_tooltip" href="/fc-paris-saint-germain/startseite/verein/583" id="583"><img alt="Paris Saint-Germain" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/583.png?lm=1522312728" title=" "/></a></td><td class="rechts hauptlink"><b>€180.00m</b><span class="icons_sprite grey-block-ten" title="€180.00m"> </span></td></tr>

# %%
# 전체 개수 확인하기
print(len(player_info))
# Out:
# 25

# %%
# 7개 정보를 담을 빈 리스트 만들기
number = []
name = []
position = []
age = []
nation = []
team = []
value = []

# %%
# plater_info에서 'td'태그만 모두 찾기
for info in player_info:
    player = info.find_all('td')
    #print(player)
    #print(player[0])
# 해당 정보를 찾아서 각 리스트에 .append로 추가하기
    number.append(player[0].text)
    name.append(player[3].text)
    position.append(player[4].text)
    age.append(player[5].text)
    nation.append(player[6].img['alt']) # 이미지 태그일때
    team.append(player[7].img['alt'])
    value.append(player[8].text.strip()) #앞 뒤 공백을 제거

# %%
# pandas로 저장하기
df = pd.DataFrame(
    {"number" : number,
     "name" : name,
     "position" : position,
     "age" : age,
     "nation" : nation,
     "team" : team,
     "value" : value}
)
df
# Out:
#    number                    name            position age        nation  \
# 0       1           Kylian Mbappé      Centre-Forward  22        France
# 1       2                  Neymar         Left Winger  29        Brazil
# 2       3              Sadio Mané         Left Winger  28       Senegal
# 3       4           Mohamed Salah        Right Winger  28         Egypt
# 4       5              Harry Kane      Centre-Forward  27       England
# 5       6         Kevin De Bruyne  Attacking Midfield  29       Belgium
# 6       7          Erling Haaland      Centre-Forward  20        Norway
# 7       8  Trent Alexander-Arnold          Right-Back  22       England
# 8       9         Raheem Sterling         Left Winger  26       England
# 9      10              João Félix      Second Striker  21      Portugal
# 10     11            Jadon Sancho        Right Winger  20       England
# 11     12         Bruno Fernandes  Attacking Midfield  26      Portugal
# 12     13          Joshua Kimmich  Defensive Midfield  26       Germany
# 13     14               Jan Oblak          Goalkeeper  28      Slovenia
# 14     15           Romelu Lukaku      Centre-Forward  27       Belgium
# 15     16           Heung-min Son         Left Winger  28  Korea, South
# 16     17             Kai Havertz  Attacking Midfield  21       Germany
# 17     18               Ansu Fati         Left Winger  18         Spain
# 18     19         Marcus Rashford         Left Winger  23       England
# 19     20         Virgil van Dijk         Centre-Back  29   Netherlands
# 20     21                 Alisson          Goalkeeper  28        Brazil
# 21     22            Lionel Messi        Right Winger  33     Argentina
# 22     23         Alphonso Davies           Left-Back  20        Canada
# 23     24        Matthijs de Ligt         Centre-Back  21   Netherlands
# 24     25        Andrew Robertson           Left-Back  26      Scotland
#
#                    team     value
# 0   Paris Saint-Germain  €180.00m
# 1   Paris Saint-Germain  €128.00m
# 2          Liverpool FC  €120.00m
# 3          Liverpool FC  €120.00m
# 4     Tottenham Hotspur  €120.00m
# 5       Manchester City  €120.00m
# 6     Borussia Dortmund  €110.00m
# 7          Liverpool FC  €110.00m
# 8       Manchester City  €110.00m
# 9       Atlético Madrid  €100.00m
# 10    Borussia Dortmund  €100.00m
# 11    Manchester United   €90.00m
# 12        Bayern Munich   €90.00m
# 13      Atlético Madrid   €90.00m
# 14          Inter Milan   €90.00m
# 15    Tottenham Hotspur   €90.00m
# 16           Chelsea FC   €81.00m
# 17         FC Barcelona   €80.00m
# 18    Manchester United   €80.00m
# 19         Liverpool FC   €80.00m
# 20         Liverpool FC   €80.00m
# 21         FC Barcelona   €80.00m
# 22        Bayern Munich   €75.00m
# 23          Juventus FC   €75.00m
# 24         Liverpool FC   €75.00m

# %%
#csv 파일로 저장하기
df.to_csv("transfermarket25.csv", index = False)
